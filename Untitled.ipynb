# %%
import pandas as pd
import csv

# %%
data = pd.read_csv("HW#6_ WeatherPy.csv", index_col=0)

# %%
DF = pd.DataFrame (data)
DF.rename_axis('city_id')
#DF.set_index('')
# Out:
#                          City Country    Lat     Lng  Max Temp  Wind Speed  \
# city_id
# 0        Vila Franca do Campo      PT  37.72  -25.43     69.80        2.24
# 1                      Castro      CL -42.48  -73.76     45.57        7.20
# 2                      Dikson      RU  73.51   80.55     41.61       12.24
# 3                 East London      ZA -33.02   27.91     57.20        4.70
# 4                       Amapa      HN  15.09  -87.97     75.20        3.36
# 5                  Bredasdorp      ZA -34.53   20.04     42.80        3.36
# 6                   Greenwood      US  32.03 -101.90     69.08        7.31
# 7                    Coquimbo      CL -29.95  -71.34     54.17        6.87
# 8                  Georgetown      GY   6.80  -58.16     77.00        4.70
# 9                  Santa Cruz      US  36.97 -122.03     68.00        8.05
# 10                     Suntar      RU  62.16  117.65     52.28        5.64
# ...

# %%
DF.to_html("data.html")
